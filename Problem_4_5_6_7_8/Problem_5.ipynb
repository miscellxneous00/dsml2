# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path="./Cosmetics_Shop.csv"

# %%
df=pd.read_csv(csv_path)

# %%
df.head()
# Out:
#    Age  Income  Gender Marital Status Buys
# 0   19     Low  Female         Single  Yes
# 1   21     Low  Female        Married   No
# 2   23  Medium    Male         Single  Yes
# 3   24  Medium  Female         Single  Yes
# 4   25    High  Female        Married  Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             48 non-null     int64
#  1   Income          48 non-null     object
#  2   Gender          48 non-null     object
#  3   Marital Status  48 non-null     object
#  4   Buys            48 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#              Age
# count  48.000000
# mean   35.166667
# std     9.893762
# min    19.000000
# 25%    27.000000
# 50%    35.000000
# 75%    43.000000
# max    55.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X=pd.get_dummies(df.drop('Buys',axis=1),drop_first=True)
y=df['Buys']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(10,8),dpi=200)
plot_tree(model,feature_names=X.columns,filled=True);

# %%
from sklearn.metrics import classification_report

# %%
y_pred=model.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.56      0.83      0.67         6
#          Yes       0.83      0.56      0.67         9
#
#     accuracy                           0.67        15
#    macro avg       0.69      0.69      0.67        15
# weighted avg       0.72      0.67      0.67        15

# %%
# model.fit(X,y)

# %%
test_1 = pd.DataFrame([{
    "Age": 18,
    "Income": "Low",
    "Gender": "Female",
    "Marital Status": "Married"
}])

# %%
sample_X = pd.get_dummies(test_1)
for col in X.columns:
    if col not in sample_X.columns:
        sample_X[col] = 0
sample_X = sample_X[X.columns]   # Arrange in order

print(model.predict(sample_X))
# Out:
# ['Yes']

# %%
test_2 = pd.DataFrame([{
    "Age": 40,
    "Income": "Medium",
    "Gender": "Female",
    "Marital Status": "Married"
}])

# %%
sample_X = pd.get_dummies(test_2)
for col in X.columns:
    if col not in sample_X.columns:
        sample_X[col] = 0
sample_X = sample_X[X.columns]   # Arrange in order

print(model.predict(sample_X))
# Out:
# ['No']

# %%
test_3 = pd.DataFrame([{
    "Age": 24,
    "Income": "Low",
    "Gender": "Male",
    "Marital Status": "Married"
}])

# %%
sample_X = pd.get_dummies(test_3)
for col in X.columns:
    if col not in sample_X.columns:
        sample_X[col] = 0
sample_X = sample_X[X.columns]   # Arrange in order

print(model.predict(sample_X))
# Out:
# ['No']

# %%
# test_4 = pd.DataFrame([{
#     "Age": 21,
#     "Income": "Low",
#     "Gender": "Male",
#     "Marital Status": "Married"
# }])

# %%
# sample_X = pd.get_dummies(test_4)
# for col in X.columns:
#     if col not in sample_X.columns:
#         sample_X[col] = 0
# sample_X = sample_X[X.columns]   # Arrange in order

# print(model.predict(sample_X))

# %%
# X.head(1)

# %%
# test_5 = pd.DataFrame([{
#     "Age": 40,
#     "Income": "High",
#     "Gender": "Female",
#     "Marital Status": "Single"
# }])

# %%
# sample_X = pd.get_dummies(test_5)
# for col in X.columns:
#     if col not in sample_X.columns:
#         sample_X[col]=0
# sample_X=sample_X[X.columns]

# %%
# print(model.predict(sample_X))

# %%
# test_demo=pd.DataFrame([{
#     "Age":22,
#     "Income":"Low",
#     "Gender":"Male",
#     "Marital Status": "Single"
# }])

# %%
# sample_X = pd.get_dummies(test_demo)

# %%
# for col in X.columns:
#     if col not in sample_X.columns:
#         sample_X[col]=0
# sample_X=sample_X[X.columns]

# %%
# print(model.predict(sample_X))
