# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier,plot_tree
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./Cosmetics_Shop.csv')

# %%
df.head()
# Out:
#    Age  Income  Gender Marital_Status Buys
# 0   19     Low  Female         Single  Yes
# 1   21     Low  Female        Married   No
# 2   23  Medium    Male         Single  Yes
# 3   24  Medium  Female         Single  Yes
# 4   25    High  Female        Married  Yes

# %%
X=df.drop('Buys',axis=1)
y = df['Buys']

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model.feature_importances_
# Out:
# array([0.432662  , 0.4800363 , 0.04374454, 0.04355717, 0.        ])

# %%
plt.figure(figsize=(10,8),dpi=200)
plot_tree(model,feature_names=X.columns,filled=True);

# %%
from sklearn.metrics import classification_report

# %%
y_pred=model.predict(X)

# %%
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       1.00      1.00      1.00        19
#          Yes       1.00      1.00      1.00        29
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
test_case = pd.DataFrame([{"Age":19,"Income":"Low","Gender":"Female","Marital_Status":"Married"}])

# %%
test_case
# Out:
#    Age Income  Gender Marital_Status
# 0   19    Low  Female        Married

# %%
test_case_dummied=pd.get_dummies(test_case)

# %%
test_case_dummied
# Out:
#    Age  Income_Low  Gender_Female  Marital_Status_Married
# 0   19        True           True                    True

# %%
X.head(1)
# Out:
#    Age  Income_Low  Income_Medium  Gender_Male  Marital_Status_Single
# 0   19        True          False        False                   True

# %%
if col in X.columns:
    if col not in test_case_dummied.columns:
        test_case_dummied[col]=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 if col in X.columns:
#       2     if col not in test_case_dummied.columns:
#       3         test_case_dummied[col]=0
#
# NameError: name 'col' is not defined
